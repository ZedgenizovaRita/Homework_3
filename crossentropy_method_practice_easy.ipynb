# %% [markdown]
# # Crossentropy method
#
# This notebook will teach you to solve reinforcement learning problems with crossentropy method. We'll follow-up by scaling everything up and using neural network policy.

# %%
# !pip install wheel==0.38.4
# !pip install setuptools==66
# !pip install gym==0.21.0

import os
# Out:
# Requirement already satisfied: wheel==0.38.4 in c:\users\mzedg\anaconda3\lib\site-packages (0.38.4)
# Requirement already satisfied: setuptools==66 in c:\users\mzedg\anaconda3\lib\site-packages (66.0.0)
# Requirement already satisfied: gym==0.21.0 in c:\users\mzedg\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\mzedg\anaconda3\lib\site-packages (from gym==0.21.0) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\mzedg\anaconda3\lib\site-packages (from gym==0.21.0) (2.2.1)

# %%
import gym
import numpy as np, pandas as pd

env = gym.make("Taxi-v3")
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n

print("n_states=%i, n_actions=%i"%(n_states,n_actions))
# Out:
# n_states=500, n_actions=6

# %% [markdown]
# # Create stochastic policy
#
# This time our policy should be a probability distribution.
#
# ```policy[s,a] = P(take action a | in state s)```
#
# Since we still use integer state and action representations, you can use a 2-dimensional array to represent the policy.
#
# Please initialize policy __uniformly__, that is, probabililities of all actions should be equal.

# %% [markdown]
# # Initialize policy (0.5pts)

# %%
policy = np.full((n_states, n_actions), 1./n_actions)
assert type(policy) in (np.ndarray,np.matrix)
assert np.allclose(policy,1./n_actions)
assert np.allclose(np.sum(policy,axis=1), 1)
print("Ok!")
# Out:
# Ok!

# %% [markdown]
# # Play the game (0.5pts)
#
# Just like before, but we also record all states and actions we took.

# %%
def generate_session(policy,t_max=10**4):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states,actions = [],[]
    total_reward = 0.
    
    s = env.reset()
    
    for t in range(t_max):
        a = np.random.choice(range(n_actions), p = policy[s])
        
        new_s,r,done,info = env.step(a)
        
        #Record state, action and add up reward to states,actions and total_reward accordingly. 
        #add state
        states.append(s)
        #add action
        actions.append(a)
        #add reward
        total_reward += r
        
        s = new_s
        if done:
            break
    return states,actions,total_reward

# %%
s,a,r = generate_session(policy)
assert type(s) == type(a) == list
assert len(s) == len(a)
assert type(r) in [float, float]

# %%
#let's see the initial reward distribution
import matplotlib.pyplot as plt
# %matplotlib inline

sample_rewards = [generate_session(policy,t_max=1000)[-1] for _ in range(200)]

plt.hist(sample_rewards,bins=20);
plt.vlines([np.percentile(sample_rewards,50)],[0],[100],label="50'th percentile",color='green')
plt.vlines([np.percentile(sample_rewards,90)],[0],[100],label="90'th percentile",color='red')
plt.legend()

# %% [markdown]
# ### Crossentropy method steps (1pts)

# %%
def select_elites(states_batch,actions_batch,rewards_batch,percentile=50):
    """
    Select states and actions from games that have rewards >= percentile
    :param states_batch: list of lists of states, states_batch[session_i][t]
    :param actions_batch: list of lists of actions, actions_batch[session_i][t]
    :param rewards_batch: list of rewards, rewards_batch[session_i][t]
    
    :returns: elite_states,elite_actions, both 1D lists of states and respective actions from elite sessions
    
    Please return elite states and actions in their original order 
    [i.e. sorted by session number and timestep within session]
    
    If you're confused, see examples below. Please don't assume that states are integers (they'll get different later).
    """ 
    reward_threshold = np.percentile(rewards_batch, percentile)
    
    elite_states = []
    
    if(len(np.array(states_batch[0]).shape) == 1):
        elite_states = np.hstack([states_batch[i] for i in range(len(rewards_batch)) if rewards_batch[i] >= reward_threshold])
    else:
        elite_states = np.vstack([states_batch[i] for i in range(len(rewards_batch)) if rewards_batch[i] >= reward_threshold])
    elite_actions = np.hstack([actions_batch[i] for i in range(len(rewards_batch)) if rewards_batch[i] >= reward_threshold])
    
    return elite_states,elite_actions

# %%
states_batch = [
    np.array([1,2,3]),   #game1
    np.array([4,2,0,2]), #game2
    np.array([3,1])      #game3
]

actions_batch = [
    np.array([0,2,4]),   #game1
    np.array([3,2,0,1]), #game2
    np.array([3,3])      #game3
]
rewards_batch = np.array([
    3,         #game1
    4,         #game2
    5,         #game3
])

test_result_0 = select_elites(states_batch,actions_batch,rewards_batch,percentile=0)
test_result_40 = select_elites(states_batch,actions_batch,rewards_batch,percentile=30)
test_result_90 = select_elites(states_batch,actions_batch,rewards_batch,percentile=90)
test_result_100 = select_elites(states_batch,actions_batch,rewards_batch,percentile=100)

assert np.all(test_result_0[0] == [1, 2, 3, 4, 2, 0, 2, 3, 1])  \
   and np.all(test_result_0[1] == [0, 2, 4, 3, 2, 0, 1, 3, 3]),\
        "For percentile 0 you should return all states and actions in chronological order"
assert np.all(test_result_40[0] == [4, 2, 0, 2, 3, 1]) and \
        np.all(test_result_40[1] ==[3, 2, 0, 1, 3, 3]),\
        "For percentile 30 you should only select states/actions from two first"
assert np.all(test_result_90[0] == [3,1]) and \
        np.all(test_result_90[1] == [3,3]),\
        "For percentile 90 you should only select states/actions from one game"
assert np.all(test_result_100[0] == [3,1]) and\
       np.all(test_result_100[1] == [3,3]),\
        "Please make sure you use >=, not >. Also double-check how you compute percentile."
print("Ok!")
# Out:
# Ok!

# %%
def update_policy(elite_states,elite_actions):
    """
    Given old policy and a list of elite states/actions from select_elites,
    return new updated policy where each action probability is proportional to
    
    policy[s_i,a_i] ~ #[occurences of si and ai in elite states/actions]
    
    Don't forget to normalize policy to get valid probabilities and handle 0/0 case.
    In case you never visited a state, set probabilities for all actions to 1./n_actions
    
    :param elite_states: 1D list of states from elite sessions
    :param elite_actions: 1D list of actions from elite sessions
    
    """
    
    new_policy = np.zeros([n_states,n_actions])
    
    #<Your code here: update probabilities for actions given elite states & actions>
    #Don't forget to set 1/n_actions for all actions in unvisited states.
    mas = [[] for _ in range(n_states)]
    for i in range(len(elite_states)):
        mas[elite_states[i]].append(elite_actions[i])
    for s_i in range(n_states):
        if len(mas[s_i]) == 0:
            new_policy[s_i] = np.full(n_actions, 1./n_actions)
        else:
            for a_i in range(n_actions):
                new_policy[s_i][a_i] = mas[s_i].count(a_i) / len(mas[s_i])
    return new_policy

# %%
elite_states, elite_actions = ([1, 2, 3, 4, 2, 0, 2, 3, 1], [0, 2, 4, 3, 2, 0, 1, 3, 3])


new_policy = update_policy(elite_states,elite_actions)

assert np.isfinite(new_policy).all(), "Your new policy contains NaNs or +-inf. Make sure you don't divide by zero."
assert np.all(new_policy>=0), "Your new policy can't have negative action probabilities"
assert np.allclose(new_policy.sum(axis=-1),1), "Your new policy should be a valid probability distribution over actions"
reference_answer = np.array([
       [ 1.        ,  0.        ,  0.        ,  0.        ,  0.        ],
       [ 0.5       ,  0.        ,  0.        ,  0.5       ,  0.        ],
       [ 0.        ,  0.33333333,  0.66666667,  0.        ,  0.        ],
       [ 0.        ,  0.        ,  0.        ,  0.5       ,  0.5       ]])
print(new_policy[:4,:5])
assert np.allclose(new_policy[:4,:5],reference_answer)
print("Ok!")
# Out:
# [[1.         0.         0.         0.         0.        ]
#  [0.5        0.         0.         0.5        0.        ]
#  [0.         0.33333333 0.66666667 0.         0.        ]
#  [0.         0.         0.         0.5        0.5       ]]
# Ok!

# %% [markdown]
# # Training loop (1pts)
# Generate sessions, select N best and fit to those.

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

def show_progress(rewards_batch,log,percentile=50,reward_range=[-990,+10]):
    """
    A convenience function that displays training progress. 
    No cool math here, just charts.
    """
    
    mean_reward = np.mean(rewards_batch)
    threshold = np.percentile(rewards_batch,percentile)
    log.append([mean_reward,threshold])

    clear_output(True)
    print("mean reward = %.3f, threshold=%.3f"%(mean_reward,threshold))
    plt.figure(figsize=[8,4])
    plt.subplot(1,2,1)
    plt.plot(list(zip(*log))[0],label='Mean rewards')
    plt.plot(list(zip(*log))[1],label='Reward thresholds')
    plt.legend()
    plt.grid()
    
    plt.subplot(1,2,2)
    plt.hist(rewards_batch,range=reward_range);
    plt.vlines([np.percentile(rewards_batch,percentile)],[0],[100],label="percentile",color='red')
    plt.legend()
    plt.grid()

    plt.show()

# %%
#reset policy just in case
policy = np.full((n_states, n_actions), 1./n_actions)

# %%
n_sessions = 250  #sample this many sessions
percentile = 70  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

log = []

for i in range(100):
    
    # %time sessions = [generate_session(policy) for _ in range(n_sessions)]
    
    states_batch,actions_batch,rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(states_batch,actions_batch,rewards_batch,percentile=50)
    
    new_policy = update_policy(elite_states,elite_actions)
    
    policy = learning_rate * new_policy + (1 - learning_rate) * policy #update policy
    
    #display results on chart
    show_progress(rewards_batch,log, percentile)
# Out:
# mean reward = -48.124, threshold=9.000

# %% [markdown]
# # Tabular crossentropy method
#
# You may have noticed that the taxi problem quickly converges from -100 to a near-optimal score and then descends back into -50/-100. This is in part because the environment has some innate randomness. Namely, the starting points of passenger/driver change from episode to episode.
#
# ### Tasks
# - __1.1__ (1 pts) Find out how the algorithm performance changes if you change different percentile and different n_samples. Show all precentiles on one graph and all n_samples on another
# - __1.2__ (1 pts) Tune the algorithm to end up with positive average score.
#
# It's okay to modify the existing code.

# %%
import gym
import numpy as np, pandas as pd

env = gym.make("Taxi-v3")
env.reset()
n_states = env.observation_space.n
n_actions = env.action_space.n
policy = 1/6. * np.ones([n_states, n_actions])
assert type(policy) in (np.ndarray,np.matrix)
assert np.allclose(policy,1./n_actions)
assert np.allclose(np.sum(policy,axis=1), 1)
s,a,r = generate_session(policy)
assert type(s) == type(a) == list
assert len(s) == len(a)
assert type(r) in [float, float]
policy = np.ones([n_states,n_actions])/n_actions 
stepCounter = 40

# %% [markdown]
# # How do different percentiles affect training efficiency?

# %%
n_sessions = 250  #sample this many sessions
percentiles = [30, 40, 50, 60, 70, 80, 90]  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

for perc in percentiles:
    curMean = []
    policy = np.ones([n_states,n_actions])/n_actions
    for i in range(stepCounter):

        # %time sessions = [generate_session(policy) for _ in range(n_sessions)]

        states_batch,actions_batch,rewards_batch = zip(*sessions)

        elite_states, elite_actions = select_elites(states_batch,actions_batch,rewards_batch,percentile=perc)
        
        new_policy = update_policy(elite_states,elite_actions)
    
        policy = learning_rate * new_policy + (1 - learning_rate) * policy
        
        curMean.append(np.mean([el for el in rewards_batch if el >= np.percentile(rewards_batch,perc)]))
    
    plt.plot(curMean, label = str(perc) + " percentiles")
    
plt.legend()
plt.grid()
plt.show()
# Out:
# CPU times: total: 4.86 s
# Wall time: 4.95 s
# CPU times: total: 4.7 s
# Wall time: 4.75 s
# CPU times: total: 4.84 s
# Wall time: 4.88 s
# CPU times: total: 4.53 s
# Wall time: 4.54 s
# CPU times: total: 4.59 s
# Wall time: 4.57 s
# CPU times: total: 4.55 s
# Wall time: 4.55 s
# CPU times: total: 4.59 s
# Wall time: 4.63 s
# CPU times: total: 4.28 s
# Wall time: 4.29 s
# CPU times: total: 4.17 s
# Wall time: 4.18 s
# CPU times: total: 4.09 s
# Wall time: 4.08 s
# CPU times: total: 4.03 s
# Wall time: 4.01 s
# CPU times: total: 3.98 s
# Wall time: 3.97 s
# CPU times: total: 3.7 s
# Wall time: 3.7 s
# CPU times: total: 3.72 s
# Wall time: 3.73 s
# CPU times: total: 3.78 s
# Wall time: 3.73 s
# CPU times: total: 3.59 s
# Wall time: 3.59 s
# CPU times: total: 3.47 s
# Wall time: 3.46 s
# CPU times: total: 3.34 s
# Wall time: 3.33 s
# CPU times: total: 3.28 s
# Wall time: 3.26 s
# CPU times: total: 3.09 s
# Wall time: 3.09 s
# CPU times: total: 3.22 s
# Wall time: 3.2 s
# CPU times: total: 2.89 s
# Wall time: 2.89 s
# CPU times: total: 2.72 s
# Wall time: 2.75 s
# CPU times: total: 2.61 s
# Wall time: 2.61 s
# CPU times: total: 2.48 s
# Wall time: 2.47 s
# CPU times: total: 2.58 s
# Wall time: 2.54 s
# CPU times: total: 2.31 s
# Wall time: 2.32 s
# CPU times: total: 2.22 s
# Wall time: 2.22 s
# CPU times: total: 2.14 s
# Wall time: 2.15 s
# CPU times: total: 2.27 s
# Wall time: 2.25 s
# CPU times: total: 2 s
# Wall time: 1.97 s
# CPU times: total: 2.03 s
# Wall time: 2.04 s
# CPU times: total: 2.08 s
# Wall time: 2.09 s
# CPU times: total: 1.94 s
# Wall time: 1.94 s
# CPU times: total: 1.58 s
# Wall time: 1.57 s
# CPU times: total: 1.59 s
# Wall time: 1.6 s
# CPU times: total: 1.58 s
# Wall time: 1.55 s
# CPU times: total: 1.19 s
# Wall time: 1.19 s
# CPU times: total: 1.03 s
# Wall time: 1.03 s
# CPU times: total: 1 s
# Wall time: 994 ms
# CPU times: total: 4.64 s
# Wall time: 4.66 s
# CPU times: total: 5.11 s
# Wall time: 5.12 s
# CPU times: total: 4.75 s
# Wall time: 4.76 s
# CPU times: total: 4.59 s
# Wall time: 4.61 s
# CPU times: total: 4.44 s
# Wall time: 4.43 s
# CPU times: total: 4.61 s
# Wall time: 4.65 s
# CPU times: total: 4.3 s
# Wall time: 4.3 s
# CPU times: total: 4.28 s
# Wall time: 4.26 s
# CPU times: total: 4.25 s
# Wall time: 4.24 s
# CPU times: total: 4.14 s
# Wall time: 4.14 s
# CPU times: total: 4.11 s
# Wall time: 4.08 s
# CPU times: total: 3.89 s
# Wall time: 3.91 s
# CPU times: total: 3.83 s
# Wall time: 3.78 s
# CPU times: total: 3.7 s
# Wall time: 3.65 s
# CPU times: total: 3.39 s
# Wall time: 3.4 s
# CPU times: total: 3.23 s
# Wall time: 3.24 s
# CPU times: total: 2.98 s
# Wall time: 3 s
# CPU times: total: 2.73 s
# Wall time: 2.69 s
# CPU times: total: 2.06 s
# Wall time: 2.05 s
# CPU times: total: 1.67 s
# Wall time: 1.66 s
# CPU times: total: 1.47 s
# Wall time: 1.47 s
# CPU times: total: 1.12 s
# Wall time: 1.13 s
# CPU times: total: 1.12 s
# Wall time: 1.09 s
# CPU times: total: 984 ms
# Wall time: 995 ms
# CPU times: total: 922 ms
# Wall time: 915 ms
# CPU times: total: 859 ms
# Wall time: 835 ms
# CPU times: total: 766 ms
# Wall time: 774 ms
# CPU times: total: 797 ms
# Wall time: 798 ms
# CPU times: total: 672 ms
# Wall time: 654 ms
# CPU times: total: 625 ms
# Wall time: 633 ms
# CPU times: total: 594 ms
# Wall time: 600 ms
# CPU times: total: 656 ms
# Wall time: 630 ms
# CPU times: total: 656 ms
# Wall time: 616 ms
# CPU times: total: 562 ms
# Wall time: 551 ms
# CPU times: total: 594 ms
# Wall time: 586 ms
# CPU times: total: 531 ms
# Wall time: 526 ms
# CPU times: total: 500 ms
# Wall time: 530 ms
# CPU times: total: 562 ms
# Wall time: 603 ms
# CPU times: total: 547 ms
# Wall time: 550 ms
# CPU times: total: 547 ms
# Wall time: 555 ms
# CPU times: total: 4.45 s
# Wall time: 4.47 s
# CPU times: total: 4.45 s
# Wall time: 4.45 s
# CPU times: total: 4.39 s
# Wall time: 4.36 s
# CPU times: total: 4.22 s
# Wall time: 4.23 s
# CPU times: total: 4.02 s
# Wall time: 3.98 s
# CPU times: total: 3.75 s
# Wall time: 3.74 s
# CPU times: total: 3.77 s
# Wall time: 3.76 s
# CPU times: total: 3.44 s
# Wall time: 3.46 s
# CPU times: total: 2.89 s
# Wall time: 2.9 s
# CPU times: total: 2.22 s
# Wall time: 2.19 s
# CPU times: total: 1.75 s
# Wall time: 1.73 s
# CPU times: total: 1.64 s
# Wall time: 1.62 s
# CPU times: total: 1.34 s
# Wall time: 1.3 s
# CPU times: total: 1.03 s
# Wall time: 1.04 s
# CPU times: total: 1 s
# Wall time: 995 ms
# CPU times: total: 859 ms
# Wall time: 845 ms
# CPU times: total: 828 ms
# Wall time: 827 ms
# CPU times: total: 828 ms
# Wall time: 818 ms
# CPU times: total: 766 ms
# Wall time: 765 ms
# CPU times: total: 703 ms
# Wall time: 695 ms
# CPU times: total: 656 ms
# Wall time: 650 ms
# CPU times: total: 625 ms
# Wall time: 600 ms
# CPU times: total: 656 ms
# Wall time: 641 ms
# CPU times: total: 562 ms
# Wall time: 565 ms
# CPU times: total: 578 ms
# Wall time: 576 ms
# CPU times: total: 578 ms
# Wall time: 583 ms
# CPU times: total: 641 ms
# Wall time: 620 ms
# CPU times: total: 688 ms
# Wall time: 675 ms
# CPU times: total: 641 ms
# Wall time: 633 ms
# CPU times: total: 609 ms
# Wall time: 611 ms
# CPU times: total: 609 ms
# Wall time: 602 ms
# CPU times: total: 594 ms
# Wall time: 600 ms
# CPU times: total: 609 ms
# Wall time: 616 ms
# CPU times: total: 594 ms
# Wall time: 548 ms
# CPU times: total: 484 ms
# Wall time: 496 ms
# CPU times: total: 469 ms
# Wall time: 479 ms
# CPU times: total: 516 ms
# Wall time: 525 ms
# CPU times: total: 609 ms
# Wall time: 602 ms
# CPU times: total: 531 ms
# Wall time: 544 ms
# CPU times: total: 516 ms
# Wall time: 516 ms
# CPU times: total: 4.53 s
# Wall time: 4.53 s
# CPU times: total: 4.53 s
# Wall time: 4.51 s
# CPU times: total: 4.42 s
# Wall time: 4.41 s
# CPU times: total: 4.42 s
# Wall time: 4.42 s
# CPU times: total: 4.36 s
# Wall time: 4.3 s
# CPU times: total: 4.27 s
# Wall time: 4.25 s
# CPU times: total: 4.19 s
# Wall time: 4.14 s
# CPU times: total: 3.52 s
# Wall time: 3.49 s
# CPU times: total: 2.94 s
# Wall time: 2.89 s
# CPU times: total: 2.28 s
# Wall time: 2.25 s
# CPU times: total: 1.67 s
# Wall time: 1.65 s
# CPU times: total: 1.36 s
# Wall time: 1.33 s
# CPU times: total: 1.31 s
# Wall time: 1.32 s
# CPU times: total: 938 ms
# Wall time: 943 ms
# CPU times: total: 875 ms
# Wall time: 871 ms
# CPU times: total: 828 ms
# Wall time: 813 ms
# CPU times: total: 812 ms
# Wall time: 827 ms
# CPU times: total: 781 ms
# Wall time: 769 ms
# CPU times: total: 672 ms
# Wall time: 653 ms
# CPU times: total: 625 ms
# Wall time: 599 ms
# CPU times: total: 688 ms
# Wall time: 691 ms
# CPU times: total: 641 ms
# Wall time: 637 ms
# CPU times: total: 734 ms
# Wall time: 682 ms
# CPU times: total: 766 ms
# Wall time: 722 ms
# CPU times: total: 766 ms
# Wall time: 768 ms
# CPU times: total: 906 ms
# Wall time: 887 ms
# CPU times: total: 875 ms
# Wall time: 855 ms
# CPU times: total: 797 ms
# Wall time: 791 ms
# CPU times: total: 1.06 s
# Wall time: 1.06 s
# CPU times: total: 969 ms
# Wall time: 972 ms
# CPU times: total: 953 ms
# Wall time: 959 ms
# CPU times: total: 1.11 s
# Wall time: 1.11 s
# CPU times: total: 1.2 s
# Wall time: 1.19 s
# CPU times: total: 1.02 s
# Wall time: 996 ms
# CPU times: total: 1.03 s
# Wall time: 1.02 s
# CPU times: total: 1.06 s
# Wall time: 1.05 s
# CPU times: total: 1.14 s
# Wall time: 1.13 s
# CPU times: total: 1.03 s
# Wall time: 1.02 s
# CPU times: total: 1.14 s
# Wall time: 1.12 s
# CPU times: total: 1.23 s
# Wall time: 1.2 s
# CPU times: total: 4.73 s
# Wall time: 4.75 s
# CPU times: total: 4.66 s
# Wall time: 4.67 s
# CPU times: total: 5.02 s
# Wall time: 5.02 s
# CPU times: total: 4.36 s
# Wall time: 4.35 s
# CPU times: total: 3.83 s
# Wall time: 3.84 s
# CPU times: total: 3.27 s
# Wall time: 3.28 s
# CPU times: total: 2.28 s
# Wall time: 2.29 s
# CPU times: total: 1.84 s
# Wall time: 1.79 s
# CPU times: total: 1.2 s
# Wall time: 1.2 s
# CPU times: total: 1.14 s
# Wall time: 1.14 s
# CPU times: total: 1.05 s
# Wall time: 1.07 s
# CPU times: total: 984 ms
# Wall time: 978 ms
# CPU times: total: 938 ms
# Wall time: 935 ms
# CPU times: total: 922 ms
# Wall time: 920 ms
# CPU times: total: 891 ms
# Wall time: 900 ms
# CPU times: total: 891 ms
# Wall time: 896 ms
# CPU times: total: 1.06 s
# Wall time: 1.07 s
# CPU times: total: 1.05 s
# Wall time: 1.05 s
# CPU times: total: 984 ms
# Wall time: 984 ms
# CPU times: total: 1.08 s
# Wall time: 1.07 s
# CPU times: total: 984 ms
# Wall time: 988 ms
# CPU times: total: 1 s
# Wall time: 998 ms
# CPU times: total: 1 s
# Wall time: 988 ms
# CPU times: total: 1.08 s
# Wall time: 1.08 s
# CPU times: total: 1.12 s
# Wall time: 1.12 s
# CPU times: total: 1.23 s
# Wall time: 1.24 s
# CPU times: total: 1.11 s
# Wall time: 1.13 s
# CPU times: total: 1.14 s
# Wall time: 1.11 s
# CPU times: total: 1.28 s
# Wall time: 1.27 s
# CPU times: total: 1.27 s
# Wall time: 1.25 s
# CPU times: total: 1.41 s
# Wall time: 1.41 s
# CPU times: total: 1.41 s
# Wall time: 1.42 s
# CPU times: total: 1.44 s
# Wall time: 1.43 s
# CPU times: total: 1.45 s
# Wall time: 1.45 s
# CPU times: total: 1.45 s
# Wall time: 1.44 s
# CPU times: total: 1.73 s
# Wall time: 1.74 s
# CPU times: total: 1.52 s
# Wall time: 1.52 s
# CPU times: total: 1.59 s
# Wall time: 1.59 s
# CPU times: total: 1.67 s
# Wall time: 1.66 s
# CPU times: total: 1.59 s
# Wall time: 1.59 s
# CPU times: total: 4.48 s
# Wall time: 4.47 s
# CPU times: total: 4.44 s
# Wall time: 4.44 s
# CPU times: total: 4.12 s
# Wall time: 4.12 s
# CPU times: total: 3.52 s
# Wall time: 3.52 s
# CPU times: total: 2.58 s
# Wall time: 2.53 s
# CPU times: total: 1.98 s
# Wall time: 1.96 s
# CPU times: total: 1.88 s
# Wall time: 1.88 s
# CPU times: total: 1.55 s
# Wall time: 1.52 s
# CPU times: total: 1.5 s
# Wall time: 1.48 s
# CPU times: total: 1.23 s
# Wall time: 1.21 s
# CPU times: total: 1.36 s
# Wall time: 1.34 s
# CPU times: total: 1.42 s
# Wall time: 1.39 s
# CPU times: total: 1.77 s
# Wall time: 1.77 s
# CPU times: total: 1.58 s
# Wall time: 1.58 s
# CPU times: total: 1.81 s
# Wall time: 1.81 s
# CPU times: total: 1.67 s
# Wall time: 1.65 s
# CPU times: total: 2 s
# Wall time: 1.99 s
# CPU times: total: 2.09 s
# Wall time: 2.05 s
# CPU times: total: 1.8 s
# Wall time: 1.8 s
# CPU times: total: 1.88 s
# Wall time: 1.83 s
# CPU times: total: 2.09 s
# Wall time: 2.1 s
# CPU times: total: 2.06 s
# Wall time: 2.06 s
# CPU times: total: 2.11 s
# Wall time: 2.11 s
# CPU times: total: 2.09 s
# Wall time: 2.05 s
# CPU times: total: 2.17 s
# Wall time: 2.07 s
# CPU times: total: 2.08 s
# Wall time: 2.08 s
# CPU times: total: 2.17 s
# Wall time: 2.18 s
# CPU times: total: 2.39 s
# Wall time: 2.31 s
# CPU times: total: 2.16 s
# Wall time: 2.15 s
# CPU times: total: 2.25 s
# Wall time: 2.25 s
# CPU times: total: 2.23 s
# Wall time: 2.24 s
# CPU times: total: 2.45 s
# Wall time: 2.35 s
# CPU times: total: 2.41 s
# Wall time: 2.35 s
# CPU times: total: 2.53 s
# Wall time: 2.49 s
# CPU times: total: 2.5 s
# Wall time: 2.51 s
# CPU times: total: 2.53 s
# Wall time: 2.53 s
# CPU times: total: 2.38 s
# Wall time: 2.35 s
# CPU times: total: 2.5 s
# Wall time: 2.44 s
# CPU times: total: 2.42 s
# Wall time: 2.42 s
# CPU times: total: 2.58 s
# Wall time: 2.59 s
# CPU times: total: 4.44 s
# Wall time: 4.46 s
# CPU times: total: 4.12 s
# Wall time: 4.12 s
# CPU times: total: 3.56 s
# Wall time: 3.55 s
# CPU times: total: 2.89 s
# Wall time: 2.86 s
# CPU times: total: 2.59 s
# Wall time: 2.59 s
# CPU times: total: 2.56 s
# Wall time: 2.57 s
# CPU times: total: 2.89 s
# Wall time: 2.89 s
# CPU times: total: 2.58 s
# Wall time: 2.57 s
# CPU times: total: 2.98 s
# Wall time: 2.98 s
# CPU times: total: 2.84 s
# Wall time: 2.85 s
# CPU times: total: 3.39 s
# Wall time: 3.38 s
# CPU times: total: 3.25 s
# Wall time: 3.25 s
# CPU times: total: 3.23 s
# Wall time: 3.22 s
# CPU times: total: 3.36 s
# Wall time: 3.36 s
# CPU times: total: 3.06 s
# Wall time: 3.06 s
# CPU times: total: 3.11 s
# Wall time: 3.12 s
# CPU times: total: 3.41 s
# Wall time: 3.4 s
# CPU times: total: 3.47 s
# Wall time: 3.44 s
# CPU times: total: 3.48 s
# Wall time: 3.42 s
# CPU times: total: 3.62 s
# Wall time: 3.6 s
# CPU times: total: 3.31 s
# Wall time: 3.31 s
# CPU times: total: 3.64 s
# Wall time: 3.64 s
# CPU times: total: 3.44 s
# Wall time: 3.44 s
# CPU times: total: 3.52 s
# Wall time: 3.52 s
# CPU times: total: 3.62 s
# Wall time: 3.64 s
# CPU times: total: 3.58 s
# Wall time: 3.58 s
# CPU times: total: 3.64 s
# Wall time: 3.64 s
# CPU times: total: 3.55 s
# Wall time: 3.55 s
# CPU times: total: 3.58 s
# Wall time: 3.54 s
# CPU times: total: 3.47 s
# Wall time: 3.47 s
# CPU times: total: 3.58 s
# Wall time: 3.61 s
# CPU times: total: 3.61 s
# Wall time: 3.63 s
# CPU times: total: 3.7 s
# Wall time: 3.73 s
# CPU times: total: 3.62 s
# Wall time: 3.64 s
# CPU times: total: 3.78 s
# Wall time: 3.79 s
# CPU times: total: 3.55 s
# Wall time: 3.51 s
# CPU times: total: 3.72 s
# Wall time: 3.75 s
# CPU times: total: 3.66 s
# Wall time: 3.7 s
# CPU times: total: 3.61 s
# Wall time: 3.6 s
# CPU times: total: 3.67 s
# Wall time: 3.66 s

# %% [markdown]
# Make a graph with several training runs with different hyperparemeters

# %%
n_sessions_ar = [50, 100, 150, 200, 250]  #sample this many sessions
perc = 70  #take this percent of session with highest rewards
learning_rate = 0.5  #add this thing to all counts for stability

for n_sessions in n_sessions_ar:
    curMean = []
    policy = np.ones([n_states,n_actions])/n_actions
    for i in range(stepCounter):

        # %time sessions = [generate_session(policy) for _ in range(n_sessions)]

        states_batch,actions_batch,rewards_batch = zip(*sessions)

        elite_states, elite_actions = select_elites(states_batch,actions_batch,rewards_batch,percentile=perc)
        
        new_policy = update_policy(elite_states,elite_actions)
    
        policy = learning_rate * new_policy + (1 - learning_rate) * policy
        
        curMean.append(np.mean([el for el in rewards_batch if el > np.percentile(rewards_batch,perc)]))
    
    plt.plot(curMean, label = str(n_sessions) + " sessions")
    
plt.legend()
plt.grid()
plt.show()
# Out:
# CPU times: total: 562 ms
# Wall time: 542 ms
# CPU times: total: 531 ms
# Wall time: 547 ms
# CPU times: total: 516 ms
# Wall time: 527 ms
# CPU times: total: 500 ms
# Wall time: 499 ms
# CPU times: total: 547 ms
# Wall time: 534 ms
# CPU times: total: 453 ms
# Wall time: 456 ms
# CPU times: total: 391 ms
# Wall time: 392 ms
# CPU times: total: 344 ms
# Wall time: 336 ms
# CPU times: total: 312 ms
# Wall time: 320 ms
# CPU times: total: 344 ms
# Wall time: 334 ms
# CPU times: total: 312 ms
# Wall time: 317 ms
# CPU times: total: 328 ms
# Wall time: 320 ms
# CPU times: total: 359 ms
# Wall time: 365 ms
# CPU times: total: 359 ms
# Wall time: 354 ms
# CPU times: total: 312 ms
# Wall time: 316 ms
# CPU times: total: 312 ms
# Wall time: 318 ms
# CPU times: total: 297 ms
# Wall time: 301 ms
# CPU times: total: 328 ms
# Wall time: 316 ms
# CPU times: total: 328 ms
# Wall time: 337 ms
# CPU times: total: 297 ms
# Wall time: 297 ms
# CPU times: total: 391 ms
# Wall time: 380 ms
# CPU times: total: 375 ms
# Wall time: 383 ms
# CPU times: total: 406 ms
# Wall time: 399 ms
# CPU times: total: 297 ms
# Wall time: 309 ms
# CPU times: total: 281 ms
# Wall time: 269 ms
# CPU times: total: 297 ms
# Wall time: 312 ms
# CPU times: total: 344 ms
# Wall time: 335 ms
# CPU times: total: 297 ms
# Wall time: 302 ms
# CPU times: total: 344 ms
# Wall time: 347 ms
# CPU times: total: 422 ms
# Wall time: 417 ms
# CPU times: total: 344 ms
# Wall time: 338 ms
# CPU times: total: 297 ms
# Wall time: 301 ms
# CPU times: total: 406 ms
# Wall time: 410 ms
# CPU times: total: 391 ms
# Wall time: 386 ms
# CPU times: total: 266 ms
# Wall time: 261 ms
# CPU times: total: 406 ms
# Wall time: 408 ms
# CPU times: total: 281 ms
# Wall time: 290 ms
# CPU times: total: 328 ms
# Wall time: 331 ms
# CPU times: total: 406 ms
# Wall time: 395 ms
# CPU times: total: 375 ms
# Wall time: 373 ms
# CPU times: total: 1.11 s
# Wall time: 1.12 s
# CPU times: total: 1.17 s
# Wall time: 1.17 s
# CPU times: total: 1.11 s
# Wall time: 1.12 s
# CPU times: total: 1.09 s
# Wall time: 1.09 s
# CPU times: total: 953 ms
# Wall time: 959 ms
# CPU times: total: 844 ms
# Wall time: 844 ms
# CPU times: total: 750 ms
# Wall time: 740 ms
# CPU times: total: 750 ms
# Wall time: 750 ms
# CPU times: total: 562 ms
# Wall time: 562 ms
# CPU times: total: 578 ms
# Wall time: 585 ms
# CPU times: total: 547 ms
# Wall time: 551 ms
# CPU times: total: 438 ms
# Wall time: 428 ms
# CPU times: total: 516 ms
# Wall time: 514 ms
# CPU times: total: 516 ms
# Wall time: 516 ms
# CPU times: total: 406 ms
# Wall time: 410 ms
# CPU times: total: 531 ms
# Wall time: 529 ms
# CPU times: total: 500 ms
# Wall time: 501 ms
# CPU times: total: 547 ms
# Wall time: 555 ms
# CPU times: total: 672 ms
# Wall time: 698 ms
# CPU times: total: 672 ms
# Wall time: 672 ms
# CPU times: total: 656 ms
# Wall time: 858 ms
# CPU times: total: 594 ms
# Wall time: 607 ms
# CPU times: total: 500 ms
# Wall time: 498 ms
# CPU times: total: 672 ms
# Wall time: 668 ms
# CPU times: total: 562 ms
# Wall time: 582 ms
# CPU times: total: 688 ms
# Wall time: 683 ms
# CPU times: total: 719 ms
# Wall time: 750 ms
# CPU times: total: 656 ms
# Wall time: 651 ms
# CPU times: total: 594 ms
# Wall time: 611 ms
# CPU times: total: 531 ms
# Wall time: 526 ms
# CPU times: total: 531 ms
# Wall time: 526 ms
# CPU times: total: 547 ms
# Wall time: 537 ms
# CPU times: total: 656 ms
# Wall time: 662 ms
# CPU times: total: 641 ms
# Wall time: 680 ms
# CPU times: total: 750 ms
# Wall time: 746 ms
# CPU times: total: 547 ms
# Wall time: 558 ms
# CPU times: total: 656 ms
# Wall time: 652 ms
# CPU times: total: 625 ms
# Wall time: 623 ms
# CPU times: total: 609 ms
# Wall time: 603 ms
# CPU times: total: 594 ms
# Wall time: 601 ms
# CPU times: total: 1.67 s
# Wall time: 1.68 s
# CPU times: total: 1.75 s
# Wall time: 1.75 s
# CPU times: total: 1.64 s
# Wall time: 1.65 s
# CPU times: total: 1.55 s
# Wall time: 1.54 s
# CPU times: total: 1.39 s
# Wall time: 1.39 s
# CPU times: total: 1.05 s
# Wall time: 1.07 s
# CPU times: total: 734 ms
# Wall time: 733 ms
# CPU times: total: 656 ms
# Wall time: 656 ms
# CPU times: total: 641 ms
# Wall time: 659 ms
# CPU times: total: 547 ms
# Wall time: 546 ms
# CPU times: total: 484 ms
# Wall time: 495 ms
# CPU times: total: 375 ms
# Wall time: 366 ms
# CPU times: total: 469 ms
# Wall time: 473 ms
# CPU times: total: 469 ms
# Wall time: 475 ms
# CPU times: total: 469 ms
# Wall time: 455 ms
# CPU times: total: 484 ms
# Wall time: 487 ms
# CPU times: total: 484 ms
# Wall time: 462 ms
# CPU times: total: 547 ms
# Wall time: 543 ms
# CPU times: total: 594 ms
# Wall time: 591 ms
# CPU times: total: 594 ms
# Wall time: 598 ms
# CPU times: total: 531 ms
# Wall time: 526 ms
# CPU times: total: 656 ms
# Wall time: 657 ms
# CPU times: total: 547 ms
# Wall time: 544 ms
# CPU times: total: 625 ms
# Wall time: 620 ms
# CPU times: total: 594 ms
# Wall time: 592 ms
# CPU times: total: 609 ms
# Wall time: 608 ms
# CPU times: total: 625 ms
# Wall time: 629 ms
# CPU times: total: 578 ms
# Wall time: 579 ms
# CPU times: total: 578 ms
# Wall time: 607 ms
# CPU times: total: 672 ms
# Wall time: 672 ms
# CPU times: total: 812 ms
# Wall time: 808 ms
# CPU times: total: 641 ms
# Wall time: 647 ms
# CPU times: total: 750 ms
# Wall time: 743 ms
# CPU times: total: 672 ms
# Wall time: 672 ms
# CPU times: total: 750 ms
# Wall time: 763 ms
# CPU times: total: 734 ms
# Wall time: 734 ms
# CPU times: total: 719 ms
# Wall time: 724 ms
# CPU times: total: 719 ms
# Wall time: 711 ms
# CPU times: total: 781 ms
# Wall time: 777 ms
# CPU times: total: 828 ms
# Wall time: 829 ms
# CPU times: total: 2.22 s
# Wall time: 2.21 s
# CPU times: total: 2.22 s
# Wall time: 2.25 s
# CPU times: total: 2.23 s
# Wall time: 2.21 s
# CPU times: total: 2.16 s
# Wall time: 2.2 s
# CPU times: total: 2.09 s
# Wall time: 2.1 s
# CPU times: total: 1.91 s
# Wall time: 1.91 s
# CPU times: total: 1.58 s
# Wall time: 1.57 s
# CPU times: total: 1.28 s
# Wall time: 1.28 s
# CPU times: total: 984 ms
# Wall time: 983 ms
# CPU times: total: 906 ms
# Wall time: 912 ms
# CPU times: total: 844 ms
# Wall time: 845 ms
# CPU times: total: 812 ms
# Wall time: 803 ms
# CPU times: total: 812 ms
# Wall time: 805 ms
# CPU times: total: 641 ms
# Wall time: 637 ms
# CPU times: total: 734 ms
# Wall time: 732 ms
# CPU times: total: 797 ms
# Wall time: 788 ms
# CPU times: total: 953 ms
# Wall time: 970 ms
# CPU times: total: 828 ms
# Wall time: 828 ms
# CPU times: total: 766 ms
# Wall time: 766 ms
# CPU times: total: 781 ms
# Wall time: 781 ms
# CPU times: total: 625 ms
# Wall time: 625 ms
# CPU times: total: 828 ms
# Wall time: 828 ms
# CPU times: total: 828 ms
# Wall time: 828 ms
# CPU times: total: 906 ms
# Wall time: 907 ms
# CPU times: total: 844 ms
# Wall time: 844 ms
# CPU times: total: 1 s
# Wall time: 1 s
# CPU times: total: 734 ms
# Wall time: 735 ms
# CPU times: total: 891 ms
# Wall time: 891 ms
# CPU times: total: 891 ms
# Wall time: 891 ms
# CPU times: total: 891 ms
# Wall time: 891 ms
# CPU times: total: 891 ms
# Wall time: 891 ms
# CPU times: total: 875 ms
# Wall time: 867 ms
# CPU times: total: 812 ms
# Wall time: 816 ms
# CPU times: total: 906 ms
# Wall time: 925 ms
# CPU times: total: 906 ms
# Wall time: 935 ms
# CPU times: total: 938 ms
# Wall time: 928 ms
# CPU times: total: 1.11 s
# Wall time: 1.11 s
# CPU times: total: 922 ms
# Wall time: 920 ms
# CPU times: total: 922 ms
# Wall time: 926 ms
# CPU times: total: 938 ms
# Wall time: 926 ms
# CPU times: total: 2.81 s
# Wall time: 2.82 s
# CPU times: total: 2.64 s
# Wall time: 2.66 s
# CPU times: total: 2.56 s
# Wall time: 2.57 s
# CPU times: total: 2.61 s
# Wall time: 2.73 s
# CPU times: total: 2.27 s
# Wall time: 2.28 s
# CPU times: total: 1.7 s
# Wall time: 1.73 s
# CPU times: total: 1.36 s
# Wall time: 1.35 s
# CPU times: total: 1.11 s
# Wall time: 1.11 s
# CPU times: total: 1.05 s
# Wall time: 1.06 s
# CPU times: total: 1.12 s
# Wall time: 1.14 s
# CPU times: total: 1.02 s
# Wall time: 1.03 s
# CPU times: total: 844 ms
# Wall time: 843 ms
# CPU times: total: 797 ms
# Wall time: 793 ms
# CPU times: total: 781 ms
# Wall time: 774 ms
# CPU times: total: 750 ms
# Wall time: 750 ms
# CPU times: total: 812 ms
# Wall time: 814 ms
# CPU times: total: 781 ms
# Wall time: 810 ms
# CPU times: total: 797 ms
# Wall time: 786 ms
# CPU times: total: 906 ms
# Wall time: 907 ms
# CPU times: total: 828 ms
# Wall time: 833 ms
# CPU times: total: 797 ms
# Wall time: 798 ms
# CPU times: total: 812 ms
# Wall time: 802 ms
# CPU times: total: 953 ms
# Wall time: 983 ms
# CPU times: total: 1.06 s
# Wall time: 1.14 s
# CPU times: total: 922 ms
# Wall time: 925 ms
# CPU times: total: 812 ms
# Wall time: 819 ms
# CPU times: total: 844 ms
# Wall time: 864 ms
# CPU times: total: 781 ms
# Wall time: 779 ms
# CPU times: total: 1.25 s
# Wall time: 1.29 s
# CPU times: total: 1.02 s
# Wall time: 1.01 s
# CPU times: total: 984 ms
# Wall time: 1.01 s
# CPU times: total: 1.02 s
# Wall time: 1.06 s
# CPU times: total: 1.14 s
# Wall time: 1.16 s
# CPU times: total: 1.02 s
# Wall time: 1.02 s
# CPU times: total: 1.03 s
# Wall time: 1.03 s
# CPU times: total: 1.23 s
# Wall time: 1.28 s
# CPU times: total: 1.25 s
# Wall time: 1.31 s
# CPU times: total: 1.05 s
# Wall time: 1.04 s
# CPU times: total: 1.31 s
# Wall time: 1.37 s
# CPU times: total: 1.23 s
# Wall time: 1.21 s

# %% [markdown]
# # Stabilize positive rewards by averaging policy across 10 games (4 pts)

# %%
def generate_session(policy,t_max=10**4):
    """
    Play game until end or for t_max ticks.
    :param policy: an array of shape [n_states,n_actions] with action probabilities
    :returns: list of states, list of actions and sum of rewards
    """
    states,actions = [],[]
    total_reward = 0.
    
    for i in range(10):
        
        s = env.reset()
        
        for t in range(t_max):
            a = np.random.choice(range(n_actions), p = policy[s])
        
            new_s,r,done,info = env.step(a)
        
            states.append(s)
        
            actions.append(a)

            total_reward += r
        
            s = new_s
            if done:
                break
    return states,actions,total_reward / 10

# %%
n_sessions = 75 #sample this many sessions
perc = 70  #take this percent of sessi.on with highest rewards
learning_rate = 0.2  #add this thing to all counts for stability

log = []
mean = []
policy = np.ones([n_states,n_actions])/n_actions
for i in range(1000):

    # %time sessions = [generate_session(policy) for _ in range(n_sessions)]

    states_batch,actions_batch,rewards_batch = zip(*sessions)

    elite_states, elite_actions = select_elites(states_batch,actions_batch,np.array(rewards_batch),percentile = 50)

    new_policy = update_policy(elite_states,elite_actions)
    
    policy = learning_rate * new_policy + (1 - learning_rate) * policy

    show_progress(rewards_batch,log)
    
    if(np.mean(rewards_batch) > 7):
        print("win!")
        break
# Out:
# mean reward = 7.017, threshold=7.100
# win!
